# %% [markdown]
# <a href="https://colab.research.google.com/github/soheldatta17/SONAR-Rock-vs-Mine-Prediction/blob/main/Rock_vs_Mine_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Data Collection and Data Processing

# %% [markdown]
# Download the dataset: https://drive.google.com/file/d/1pQxtljlNVh0DHYg-Ye7dtpDTlFceHVfa/view

# %%
#loading the dataset to a pandas Dataframe
sonar_data = pd.read_csv('/content/sonar.csv', header=None)

# %%
sonar_data.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
# number of rows and columns
sonar_data.shape
# Out:
# (208, 61)

# %%
sonar_data.describe()  #describe --> statistical measures of the data
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# ...

# %%
sonar_data[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %% [markdown]
# Understanding Distribution: This method is often used to understand the distribution of values in a column. For instance, in a classification dataset, it can show how many instances belong to each class.
# Data Analysis: This can help in identifying imbalances in the dataset, such as one class being more prevalent than another, which can be important for model training and evaluation.

# %% [markdown]
# M --> Mine
#
# R --> Rock

# %%
sonar_data.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# M   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
# R   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
#
#           7         8         9   ...        50        51        52        53  \
# 60                                ...
# M   0.149832  0.213492  0.251022  ...  0.019352  0.016014  0.011643  0.012185
# R   0.117596  0.137392  0.159325  ...  0.012311  0.010453  0.009640  0.009518
#
#           54        55        56        57        58        59
# 60
# M   0.009923  0.008914  0.007825  0.009060  0.008695  0.006930
# R   0.008567  0.007430  0.007814  0.006677  0.007078  0.006024
#
# [2 rows x 60 columns]

# %%
# separating data (features) and Labels
X = sonar_data.drop(columns=60, axis=1)
Y = sonar_data[60]

# %%
print(f"\n\nFeatures\n\n{X}")
print(f"\n\nLabels\n\n{Y}")
# Out:
# Features
#
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %% [markdown]
# Training and Test data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify=Y, random_state=1)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (208, 60) (166, 60) (42, 60)

# %%
print(X_train)
print(Y_train)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 183  0.0096  0.0404  0.0682  0.0688  0.0887  0.0932  0.0955  0.2140  0.2546
# 27   0.0177  0.0300  0.0288  0.0394  0.0630  0.0526  0.0688  0.0633  0.0624
# 149  0.0207  0.0535  0.0334  0.0818  0.0740  0.0324  0.0918  0.1070  0.1553
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 94   0.0025  0.0309  0.0171  0.0228  0.0434  0.1224  0.1947  0.1661  0.1368
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 140  0.0412  0.1135  0.0518  0.0232  0.0646  0.1124  0.1787  0.2407  0.2682
# 154  0.0117  0.0069  0.0279  0.0583  0.0915  0.1267  0.1577  0.1927  0.2361
# 131  0.1150  0.1163  0.0866  0.0358  0.0232  0.1267  0.2417  0.2661  0.4346
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
#
# ...

# %% [markdown]
# Model Training --> Logistic Regression

# %%
model = LogisticRegression()

# %%
#training the Logistic Regression model with training data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
#accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on training data : ', training_data_accuracy*100)
# Out:
# Accuracy on training data :  84.33734939759037

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy on test data : ', test_data_accuracy*100)
# Out:
# Accuracy on test data :  69.04761904761905

# %% [markdown]
# Making a Predictive System

# %% [markdown]
# The input data consists of a series of numerical features that represent the sonar readings. Each row in the dataset contain the intensity of the sonar signal at different angles or time intervals.

# %%
import numpy as np

# Assuming model is already defined and trained

# Example input data for rocks and mines
input_data_rock_1 = (
    0.0439, 0.0535, 0.0506, 0.0615, 0.0695, 0.0810, 0.0920, 0.1070, 0.1440, 0.2110,
    0.3560, 0.5180, 0.5580, 0.5690, 0.6400, 0.7100, 0.8200, 0.8930, 0.9090, 0.9020,
    0.8600, 0.7620, 0.6960, 0.5990, 0.4010, 0.2070, 0.1050, 0.0522, 0.0289, 0.0372,
    0.0578, 0.0852, 0.1270, 0.1960, 0.2750, 0.3450, 0.3760, 0.4190, 0.4650, 0.4020,
    0.2820, 0.1700, 0.1120, 0.0888, 0.0615, 0.0322, 0.0216, 0.0099, 0.0133, 0.0133,
    0.0101, 0.0104, 0.0091, 0.0056, 0.0048, 0.0036, 0.0034, 0.0030, 0.0032, 0.0028
)

input_data_rock_2 = (
    0.0298, 0.0371, 0.0428, 0.0516, 0.0616, 0.0722, 0.0927, 0.1010, 0.1470, 0.2200,
    0.3540, 0.5040, 0.5460, 0.5550, 0.5980, 0.6470, 0.7400, 0.7940, 0.8680, 0.9040,
    0.8280, 0.7640, 0.6860, 0.5930, 0.3760, 0.1960, 0.1000, 0.0518, 0.0288, 0.0320,
    0.0453, 0.0652, 0.0870, 0.1450, 0.2360, 0.3270, 0.3620, 0.3920, 0.4580, 0.4470,
    0.3050, 0.2130, 0.1300, 0.0963, 0.0722, 0.0345, 0.0210, 0.0110, 0.0153, 0.0153,
    0.0114, 0.0112, 0.0091, 0.0074, 0.0047, 0.0038, 0.0037, 0.0032, 0.0035, 0.0031
)

input_data_rock_3 = (
    0.0357, 0.0483, 0.0550, 0.0644, 0.0727, 0.0861, 0.0931, 0.1020, 0.1390, 0.2100,
    0.3450, 0.4990, 0.5440, 0.5490, 0.6170, 0.6730, 0.7730, 0.8260, 0.8760, 0.9010,
    0.8440, 0.7500, 0.6780, 0.5820, 0.3770, 0.2030, 0.1050, 0.0533, 0.0279, 0.0330,
    0.0502, 0.0778, 0.1070, 0.1640, 0.2550, 0.3380, 0.3760, 0.4130, 0.4720, 0.4260,
    0.2860, 0.1860, 0.1100, 0.0860, 0.0640, 0.0311, 0.0194, 0.0100, 0.0138, 0.0138,
    0.0097, 0.0093, 0.0080, 0.0061, 0.0042, 0.0035, 0.0035, 0.0032, 0.0031, 0.0027
)

input_data_mine_1 = (
    0.0307, 0.0523, 0.0653, 0.0521, 0.0611, 0.0577, 0.0665, 0.0664, 0.1460, 0.2792,
    0.3877, 0.4992, 0.4981, 0.4972, 0.5607, 0.7339, 0.8230, 0.9173, 0.9975, 0.9911,
    0.8240, 0.6498, 0.5980, 0.4862, 0.3150, 0.1543, 0.0989, 0.0284, 0.1008, 0.2636,
    0.2694, 0.2930, 0.2925, 0.3998, 0.3660, 0.3172, 0.4609, 0.4374, 0.1820, 0.3376,
    0.6202, 0.4448, 0.1863, 0.1420, 0.0589, 0.0576, 0.0672, 0.0269, 0.0245, 0.0190,
    0.0063, 0.0321, 0.0189, 0.0137, 0.0277, 0.0152, 0.0052, 0.0121, 0.0124, 0.0055
)

input_data_mine_2 = (
    0.0376, 0.0523, 0.0642, 0.0529, 0.0602, 0.0557, 0.0674, 0.0673, 0.1520, 0.2892,
    0.3967, 0.5112, 0.5011, 0.4992, 0.5637, 0.7419, 0.8290, 0.9193, 1.0075, 0.9931,
    0.8240, 0.6598, 0.6040, 0.4952, 0.3180, 0.1583, 0.0999, 0.0304, 0.1038, 0.2676,
    0.2744, 0.2970, 0.2965, 0.4058, 0.3720, 0.3212, 0.4659, 0.4424, 0.1860, 0.3416,
    0.6242, 0.4498, 0.1903, 0.1460, 0.0609, 0.0586, 0.0692, 0.0289, 0.0265, 0.0200,
    0.0083, 0.0341, 0.0199, 0.0147, 0.0297, 0.0162, 0.0057, 0.0131, 0.0134, 0.0065
)

input_data_mine_3 = (
    0.0387, 0.0533, 0.0652, 0.0531, 0.0615, 0.0587, 0.0685, 0.0684, 0.1490, 0.2772,
    0.3907, 0.5022, 0.5041, 0.4992, 0.5627, 0.7359, 0.8240, 0.9163, 1.0035, 0.9921,
    0.8230, 0.6558, 0.6020, 0.4912, 0.3170, 0.1573, 0.0999, 0.0294, 0.1028, 0.2656,
    0.2724, 0.2940, 0.2935, 0.4028, 0.3690, 0.3192, 0.4629, 0.4394, 0.1840, 0.3396,
    0.6212, 0.4478, 0.1883, 0.1440, 0.0599, 0.0576, 0.0682, 0.0279, 0.0255, 0.0180,
    0.0073, 0.0311, 0.0189, 0.0137, 0.0277, 0.0152, 0.0052, 0.0121, 0.0124, 0.0055
)

# List of input data and their actual results
data_points = [
    (input_data_rock_1, 'R'),
    (input_data_rock_2, 'R'),
    (input_data_rock_3, 'R'),
    (input_data_mine_1, 'M'),
    (input_data_mine_2, 'M'),
    (input_data_mine_3, 'M')
]

# Function to predict and compare results
def predict_and_compare(data_points):
    for data, actual_result in data_points:
        # Convert the input data to a numpy array and reshape it
        input_data_as_numpy_array = np.asarray(data)
        input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

        # Predict the result
        prediction = model.predict(input_data_reshaped)

        # Print the prediction and compare it with the actual result
        print(f"Prediction: {prediction[0]}, Actual: {actual_result}")
        if prediction[0] == actual_result:
            print("Correct")
        else:
            print("Incorrect")

# Call the function with the list of data points
predict_and_compare(data_points)
# Out:
# Prediction: R, Actual: R
# Correct
# Prediction: R, Actual: R
# Correct
# Prediction: R, Actual: R
# Correct
# Prediction: M, Actual: M
# Correct
# Prediction: M, Actual: M
# Correct
# Prediction: M, Actual: M
# Correct
